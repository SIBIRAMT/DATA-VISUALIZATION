# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = {
    "Score": [116, 103, 103, 107, 119, 105, 115, 141, 169],
    "Out/Not Out": ["Out", "Out", "Out", "Out", "Out", "Not Out", "Out", "Out", "Out"],
    "Against": ["Australia", "New Zealand", "England", "Australia", "South Africa", "New Zealand", "Australia", "Australia", "Australia"],
    "Batting Order": [6, 5, 5, 5, 4, 4, 2, 4, 2],
    "Inn.": [2, 2, 2, 2, 1, 4, 2, 4, 2],
    "Strike Rate": [None, None, None, None, None, None, None, None, None],
    "Venue": ["Adelaide Oval", "M. Chinnaswamy Stadium", "Vidarbha Cricket Association Stadium", "M. A. Chidambaram Stadium", "Wanderers Stadium", "Basin Reserve", "Adelaide Oval", "Adelaide Oval", "Melbourne Cricket Ground"],
    "Column1": ["Adelaide", "Bangalore", "Nagpur", "Chennai", "Johannesburg", "Wellington", "Adelaide", "Adelaide", "Melbourne"],
    "H/A": ["Away", "Home", "Home", "Home", "Away", "Away", "Away", "Away", "Away"],
    "Date": ["24-01-2012", "31-08-2012", "13-12-2012", "22-02-2013", "18-12-2013", "14-02-2014", "09-12-2014", "09-12-2014", "26-12-2014"],
    "Result": ["Lost", "Won", "Drawn", "Won", "Drawn", "Drawn", "Lost", "Lost", "Drawn"],
    "Format": ["Test", "Test", "Test", "Test", "Test", "Test", "Test", "Test", "Test"],
    "Man of the Match": ["No", "Yes", "No", "No", "No", "No", "No", "No", "No"],
    "Captain": ["No", "No", "No", "No", "No", "No", "Yes", "Yes", "No"]
}

df = pd.DataFrame(data)

# Basic data summary
print(df.describe())

# Visualize the data (for example, a bar plot)
sns.countplot(x="Result", data=df)
plt.title("Match Results")
plt.show()
# Out:
#             Score  Batting Order      Inn.
# count    9.000000       9.000000  9.000000
# mean   119.777778       4.111111  2.333333
# std     21.953233       1.364225  1.000000
# min    103.000000       2.000000  1.000000
# 25%    105.000000       4.000000  2.000000
# 50%    115.000000       4.000000  2.000000
# 75%    119.000000       5.000000  2.000000
# max    169.000000       6.000000  4.000000
